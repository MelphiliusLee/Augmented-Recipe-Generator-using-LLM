# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("gdrive/My Drive/dev_data.csv")

# %%
data.shape
# Out:
# (123114, 4)

# %%
data.head()
# Out:
#                     title                                        ingredients  \
# 0         Haddock In Milk  ['500 ml skim milk (enough to half fill a sauc...
# 1  Cream Of Paresian Soup  ['1 pkg. frozen California medley vegetables',...
# 2   Cinnamon Rice Pudding  ['3 1/2 c. (2%) low-fat milk (divided)', '1/2 ...
# 3               Meat Loaf  ['1 c. bread crumbs', '1 c. sweet milk', '1 1/...
# 4       Sour Cream Latkes  ['1 c. flour or whole wheat', '3/4 tsp. soda',...
#
#                                           directions  \
# 0  ["Pour you milk into a saucepan and leave to b...
# 1  ["Mix all together and heat through.", "Put in...
# 2  ["Combine 3 cups milk, uncooked rice and next ...
# 3  ["Soak bread crumbs in the milk; add salt, pep...
# 4  ["Whip for mixing, no spoon. Put 2 tablespoons...
#
#                                                  NER
# 0                 ['haddock', 'red onion', 'pepper']
# 1  ['frozen california medley vegetables', 'cream...
# 2  ['golden raisins', 'egg', 'sugar', 'vanilla ex...
# 3  ['sweet milk', 'ground pork', 'pepper', 'chili...
# 4    ['sour cream', 'soda', 'flour', 'milk', 'salt']

# %%
from numpy.random import default_rng
data = data[0:2000]

# %%
data.shape
# Out:
# (2000, 4)

# %%
import ast
# Convert the string representation of the list into an actual list
data['directions'] = data['directions'].apply(ast.literal_eval)
data['NER'] = data['NER'].apply(ast.literal_eval)
data['ingredients'] = data['ingredients'].apply(ast.literal_eval)

# %%
#get all unique ingredients
ingredients_vocab = set(ingredient for sublist in data['NER'] for ingredient in sublist)

# %%
ingredients_list = list(data['ingredients'])
directions_list = list(data['directions'])
title_list = list(data['title'])
ner_list = list(data['NER'])

# %%
def preprocess_dataset(ingredients_list, directions_list, title_list, ner_list):
    # Initialize an empty list to store preprocessed data
    processed_data = []

    # Iterate over each recipe in the dataset
    for ingredients, directions, title, ner in zip(ingredients_list, directions_list, title_list, ner_list):
        # Combine ingredients and directions into a single string with spaces between words/symbols
        ingredients_text = ', '.join(ingredients)
        directions_text = ' '.join(directions)
        ner_text = ', '.join(ner)
        #context = f"Title: {title} Ingredients: {ingredients_text} Instructions: {directions_text}"
        question = f"I have {ner_text}. Give me some cooking ideas."
        answer = f"You can make {title} with {ingredients_text}. Here's the instruction: {directions_text}"
        processed_data.append({
              "input_text": question,
              "target_text": answer
          })
        question = f"How to make {title}?"
        processed_data.append({
              "input_text": question,
              "target_text": answer
              })

    return processed_data

# %%
df = pd.DataFrame(preprocess_dataset(ingredients_list, directions_list, title_list, ner_list))

# %%
df.head()
# Out:
#                                           input_text  \
# 0  I have haddock, red onion, pepper. Give me som...
# 1                       How to make Haddock In Milk?
# 2  I have frozen california medley vegetables, cr...
# 3                How to make Cream Of Paresian Soup?
# 4  I have golden raisins, egg, sugar, vanilla ext...
#
#                                          target_text
# 0  You can make Haddock In Milk with 500 ml skim ...
# 1  You can make Haddock In Milk with 500 ml skim ...
# 2  You can make Cream Of Paresian Soup with 1 pkg...
# 3  You can make Cream Of Paresian Soup with 1 pkg...
# 4  You can make Cinnamon Rice Pudding with 3 1/2 ...

# %%
df.shape
# Out:
# (4000, 2)

# %%
df.to_csv('gdrive/My Drive/recipe_dataset_10000.csv', index=False)
